# %% [markdown]
# Customer segmentation:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans
from sklearn.preprocessing import LabelEncoder

# %%
df=pd.read_csv('/content/customer_segmentation.csv')
df.head()
# Out:
#      ID  Year_Birth   Education  ... Z_CostContact  Z_Revenue  Response
# 0  5524        1957  Graduation  ...             3         11         1
# 1  2174        1954  Graduation  ...             3         11         0
# 2  4141        1965  Graduation  ...             3         11         0
# 3  6182        1984  Graduation  ...             3         11         0
# 4  5324        1981         PhD  ...             3         11         0
#
# [5 rows x 29 columns]

# %%
print('Rows and columns:',df.shape)
df.info()
# Out:
# Rows and columns: (2240, 29)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4   Income               2216 non-null   float64
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  ID   Year_Birth  ...  Z_Revenue     Response
# count   2240.000000  2240.000000  ...     2240.0  2240.000000
# mean    5592.159821  1968.805804  ...       11.0     0.149107
# std     3246.662198    11.984069  ...        0.0     0.356274
# min        0.000000  1893.000000  ...       11.0     0.000000
# 25%     2828.250000  1959.000000  ...       11.0     0.000000
# 50%     5458.500000  1970.000000  ...       11.0     0.000000
# 75%     8427.750000  1977.000000  ...       11.0     0.000000
# max    11191.000000  1996.000000  ...       11.0     1.000000
#
# [8 rows x 26 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Complain                0
# Z_CostContact           0
# Z_Revenue               0
# Response                0
# dtype: int64

# %%
df['Income']=df['Income'].fillna(df['Income'].median()).astype(int)
df.isnull().sum()
# Out:
# ID                     0
# Year_Birth             0
# Education              0
# Marital_Status         0
# Income                 0
# Kidhome                0
# Teenhome               0
# Dt_Customer            0
# Recency                0
# MntWines               0
# MntFruits              0
# MntMeatProducts        0
# MntFishProducts        0
# MntSweetProducts       0
# MntGoldProds           0
# NumDealsPurchases      0
# NumWebPurchases        0
# NumCatalogPurchases    0
# NumStorePurchases      0
# NumWebVisitsMonth      0
# AcceptedCmp3           0
# AcceptedCmp4           0
# AcceptedCmp5           0
# AcceptedCmp1           0
# AcceptedCmp2           0
# Complain               0
# Z_CostContact          0
# Z_Revenue              0
# Response               0
# dtype: int64

# %%
lb_encoder=LabelEncoder()
df['Education']=lb_encoder.fit_transform(df['Education'])
df['Marital_Status']=lb_encoder.fit_transform(df['Marital_Status'])
df.head()
# Out:
#      ID  Year_Birth  Education  ...  Z_CostContact  Z_Revenue  Response
# 0  5524        1957          2  ...              3         11         1
# 1  2174        1954          2  ...              3         11         0
# 2  4141        1965          2  ...              3         11         0
# 3  6182        1984          2  ...              3         11         0
# 4  5324        1981          4  ...              3         11         0
#
# [5 rows x 29 columns]

# %%
df.head()
# Out:
#      ID  Year_Birth  Education  ...  Z_CostContact  Z_Revenue  Dt_Customer_days
# 0  5524        1957          2  ...              3         11                36
# 1  2174        1954          2  ...              3         11               586
# 2  4141        1965          2  ...              3         11               387
# 3  6182        1984          2  ...              3         11               560
# 4  5324        1981          4  ...              3         11               538
#
# [5 rows x 28 columns]

# %%
model1=KMeans(n_clusters=2)
model1.fit(df)
# Out:
# KMeans(n_clusters=2)

# %%
from sklearn.metrics import silhouette_score



silhouette_avg = silhouette_score(df, model1.labels_)
print(f"Silhouette Score: {silhouette_avg}")
# Out:
# Silhouette Score: 0.5652602601450785

# %%
from sklearn.decomposition import PCA


pca = PCA(n_components=2)
df_pca = pca.fit_transform(df)


df_pca = pd.DataFrame(data=df_pca, columns=['PC1', 'PC2'])
df_pca['Cluster'] = model1.labels_

display(df_pca.head())
# Out:
#             PC1          PC2  Cluster
# 0   5904.381207   -79.566173        1
# 1  -5902.723122 -3407.103442        0
# 2  19372.471922 -1484.149124        1
# 3 -25592.866394   634.018567        0
# 4   6053.047055  -277.906838        1

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='PC1', y='PC2', hue='Cluster', data=df_pca, palette='Reds', legend='full')
plt.title('Customer Segments based on PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid(True)
plt.show()
